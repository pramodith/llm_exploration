# %%
# %pip install trl
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/139.1 kB ? eta -:--:--
#      ---------------------- ---------------- 81.9/139.1 kB 4.5 MB/s eta 0:00:01
#      -------------------------------------- 139.1/139.1 kB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/78.9 kB ? eta -:--:--
#      ---------------------------------------- 78.9/78.9 kB 4.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#       --------------------------------------- 0.2/8.2 MB 4.1 MB/s eta 0:00:02
#      -- ------------------------------------- 0.5/8.2 MB 4.7 MB/s eta 0:00:02
#      --- ------------------------------------ 0.6/8.2 MB 4.9 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.8/8.2 MB 5.4 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.1/8.2 MB 5.0 MB/s eta 0:00:02
#      ------ --------------------------------- 1.3/8.2 MB 5.0 MB/s eta 0:00:02
# ...
